# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
l_stops = pd.read_csv("CTA_-_System_Information_-_List_of__L__Stops_-_Map.csv")

# %%
l_stops
# Out:
#      STOP_ID                               STOP_NAME          STATION_NAME  \
# 0      30162                18th (54th/Cermak-bound)                  18th
# 1      30161                       18th (Loop-bound)                  18th
# 2      30022                35th/Archer (Loop-bound)           35th/Archer
# 3      30023              35th/Archer (Midway-bound)           35th/Archer
# 4      30214         35-Bronzeville-IIT (63rd-bound)  35th-Bronzeville-IIT
# ..       ...                                     ...                   ...
# 295    30129  Western (O'Hare Branch) (O'Hare-bound)               Western
# 296    30385                     Wilson (Loop-bound)                Wilson
# 297    30106                     Wilson (95th-bound)                Wilson
# 298    30105                   Wilson (Howard-bound)                Wilson
# 299    30386                   Wilson (Linden-bound)                Wilson
#
# ...

# %%
coords = pd.DataFrame(l_stops.Location.apply(lambda x: x[1:-1].split(",")).tolist(), columns=['lat', 'long']).astype('float')

# %%
fig = plt.figure(dpi=120)
plt.scatter(coords.long, coords.lat, alpha=0.3)
plt.axis('equal')
plt.grid()
plt.show()
